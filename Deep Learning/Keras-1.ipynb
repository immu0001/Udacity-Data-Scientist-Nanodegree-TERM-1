# %%
conda install keras
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::numba==0.44.1=py37h962f231_0
#   - defaults/linux-64::anaconda==2019.07=py37_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::numba==0.44.1=py37h962f231_0
#   - defaults/linux-64::anaconda==2019.07=py37_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/imran/anaconda3
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     ca-certificates-2019.11.27 |                0         124 KB
#     certifi-2019.11.28         |           py37_0         153 KB
#     conda-4.8.1                |           py37_0         2.8 MB
#     keras-2.2.4                |                0           5 KB
#     keras-base-2.2.4           |           py37_0         421 KB
#     tbb-2019.8                 |       hfd86e86_0         1.1 MB
#     tensorboard-1.15.0         |     pyhb230dea_0         3.2 MB
#     tensorflow-1.15.0          |mkl_py37h28c19af_0           4 KB
#     tensorflow-base-1.15.0     |mkl_py37he1670d9_0        87.5 MB
#     tensorflow-estimator-1.15.1|     pyh2649769_0         271 KB
#     ------------------------------------------------------------
#                                            Total:        95.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/linux-64::_anaconda_depends-2019.03-py37_0
#   keras              pkgs/main/linux-64::keras-2.2.4-0
#   keras-base         pkgs/main/linux-64::keras-base-2.2.4-py37_0
#   tbb                pkgs/main/linux-64::tbb-2019.8-hfd86e86_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                               2019.5.15-0 --> 2019.11.27-0
#   certifi                                  2019.6.16-py37_0 --> 2019.11.28-py37_0
#   conda                                       4.7.12-py37_0 --> 4.8.1-py37_0
#   openssl                                 1.1.1c-h7b6447c_1 --> 1.1.1d-h7b6447c_3
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.07-py37_0 --> custom-py37_1
#   tensorboard                            2.0.0-pyhb230dea_0 --> 1.15.0-pyhb230dea_0
#   tensorflow                       2.0.0-mkl_py37h66b46cc_0 --> 1.15.0-mkl_py37h28c19af_0
#   tensorflow-base                  2.0.0-mkl_py37h9204916_0 --> 1.15.0-mkl_py37he1670d9_0
#   tensorflow-estima~                     2.0.0-pyh2649769_0 --> 1.15.1-pyh2649769_0
#
#
#
# Downloading and Extracting Packages
# tbb-2019.8           | 1.1 MB    | ##################################### | 100%
# tensorflow-base-1.15 | 87.5 MB   | ##################################### | 100%
# certifi-2019.11.28   | 153 KB    | ##################################### | 100%
# anaconda-custom      | 3 KB      | ##################################### | 100%
# keras-base-2.2.4     | 421 KB    | ##################################### | 100%
# tensorflow-1.15.0    | 4 KB      | ##################################### | 100%
# ca-certificates-2019 | 124 KB    | ##################################### | 100%
# tensorflow-estimator | 271 KB    | ##################################### | 100%
# conda-4.8.1          | 2.8 MB    | ##################################### | 100%
# _anaconda_depends-20 | 6 KB      | ##################################### | 100%
# tensorboard-1.15.0   | 3.2 MB    | ##################################### | 100%
# keras-2.2.4          | 5 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.callbacks import Callback
from keras.initializers import VarianceScaling 
import numpy as np 


lastEpoch = 0


class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='val_loss', value=0.008, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose
    def on_epoch_end(self, epoch, logs={}):
        global lastEpoch
        current = logs.get("loss")         
        if current != None and current < self.value:
            self.model.stop_training = True
            lastEpoch = epoch + 1


x = np.array([
    [0,0], [0,1],
    [1,0], [1,1]
])
y = np.array([
    [0], [1], 
    [1], [0]
])

model = Sequential()
model.add(Dense(8, 
                input_dim = 2, 
                use_bias = False, 
                kernel_initializer = VarianceScaling()))
model.add(Activation('tanh'))
model.add(Dense(1, 
                use_bias = False, 
                kernel_initializer = VarianceScaling()))
model.add(Activation('tanh'))
model.compile(loss = "mean_squared_error", 
              optimizer = SGD(lr = 0.6, 
                              momentum = 0.6))

model.fit(x, y, 
          verbose = 1, 
          batch_size = 4, 
          epochs = 10000, 
          callbacks = [
            EarlyStoppingByLossVal()
          ])

print(model.predict_proba(x))
print("Last epoch: " + str(lastEpoch))
# Out:
# WARNING:tensorflow:From /home/imran/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# Epoch 1/10000
# 4/4 [==============================] - 2s 405ms/step - loss: 0.2672
# Epoch 2/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2293
# Epoch 3/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2246
# Epoch 4/10000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2226
# Epoch 5/10000
# 4/4 [==============================] - 0s 681us/step - loss: 0.2185
# Epoch 6/10000
# 4/4 [==============================] - 0s 519us/step - loss: 0.2118
# Epoch 7/10000
# 4/4 [==============================] - 0s 844us/step - loss: 0.2030
# Epoch 8/10000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1934
# Epoch 9/10000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1840
# Epoch 10/10000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1741
# Epoch 11/10000
# 4/4 [==============================] - 0s 743us/step - loss: 0.1640
# Epoch 12/10000
# 4/4 [==============================] - 0s 562us/step - loss: 0.1532
# Epoch 13/10000
# 4/4 [==============================] - 0s 820us/step - loss: 0.1415
# Epoch 14/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1295
# Epoch 15/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1166
# Epoch 16/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1032
# Epoch 17/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0896
# Epoch 18/10000
# 4/4 [==============================] - 0s 636us/step - loss: 0.0765
# Epoch 19/10000
# 4/4 [==============================] - 0s 572us/step - loss: 0.0642
# Epoch 20/10000
# 4/4 [==============================] - 0s 527us/step - loss: 0.0534
# Epoch 21/10000
# 4/4 [==============================] - 0s 680us/step - loss: 0.0442
# Epoch 22/10000
# 4/4 [==============================] - 0s 834us/step - loss: 0.0366
# Epoch 23/10000
# 4/4 [==============================] - 0s 836us/step - loss: 0.0304
# Epoch 24/10000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0255
# Epoch 25/10000
# 4/4 [==============================] - 0s 435us/step - loss: 0.0216
# Epoch 26/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 27/10000
# 4/4 [==============================] - 0s 488us/step - loss: 0.0161
# Epoch 28/10000
# 4/4 [==============================] - 0s 913us/step - loss: 0.0141
# Epoch 29/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 30/10000
# 4/4 [==============================] - 0s 644us/step - loss: 0.0112
# Epoch 31/10000
# 4/4 [==============================] - 0s 629us/step - loss: 0.0101
# Epoch 32/10000
# 4/4 [==============================] - 0s 622us/step - loss: 0.0092
# Epoch 33/10000
# 4/4 [==============================] - 0s 745us/step - loss: 0.0084
# Epoch 34/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0078
# [[0.        ]
#  [0.877808  ]
#  [0.8868566 ]
#  [0.03232758]]
# Last epoch: 34
